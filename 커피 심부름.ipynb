# %%
def solution(order):
    answer = 0
    for menu in order:
        if "americano" in menu or menu == "anything":
            answer += 4500
        elif "latte" in menu:
            answer += 5000

    return answer

# %%
my_string = "He11oWor1d"
overwrite_string = "lloWorl"
s = 2
answer = ''
index = 0

print(s+len(overwrite_string))

for i in range(s, (s + len(overwrite_string))):
    my_string = my_string.replace(my_string[i], overwrite_string[index],1)
    index += 1
answer = my_string
print(answer)
# Out:
# 9
# HelloWorld

# %%
def solution(my_string, overwrite_string, s):
    answer = ''
    index = 0

    for i in range(s, (s + len(overwrite_string))):
        answer = my_string.replace(my_string[s], overwrite_string[index])
        index += 1


    return answer
