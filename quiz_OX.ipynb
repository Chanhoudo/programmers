# %%
def solution(quiz):
    answer = []

    for q in quiz:
        ex, result = q.split('=')
        if eval(ex) == int(result):
            answer.append('O')
        else:
            answer.append('X')

    return answer

# %%
def solution(quiz):
    answer = []

    for q in quiz:
        s = q.split(' ')
        oper = ''
        num = 0
        i = 0
        while True:
            if s[i] == '=':
                if num == int(s[i+1]):
                    answer.append('O')
                else:
                    answer.append('X')
                print(num, s[i+1])
                break
            elif s[i].isdigit():
                if oper == '+':
                    num += int(s[i])
                elif oper == '-':
                    num -= int(s[i])
                else:
                    num = int(s[i])
            else:
                oper = s[i]
            i += 1
    return answer
